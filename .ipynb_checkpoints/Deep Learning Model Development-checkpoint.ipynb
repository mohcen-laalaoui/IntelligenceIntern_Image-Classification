# %% [markdown]
# # **Task 2 - Deep Learning Model Development**

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import torch 
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision  
import torchvision.transforms as transforms  
from torchvision import datasets, models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader , random_split
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ### GPU Support

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ### Load and Process Multiple Images

# %%
dataset_path = "blood_cell_images/"

# %% [markdown]
# ###  Convert images to numpy format for visualization

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),  
    transforms.ToTensor(), 
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  
])

# %% [markdown]
# ### Load Dataset

# %%
train_dataset = datasets.ImageFolder(root=dataset_path, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
print("Classes:", train_dataset.classes)
# Out:
# Classes: ['class_0', 'class_1']

# %%
def imshow(img):
    img = img / 2 + 0.5  
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %% [markdown]
# ### Get a Batch of Images

# %%
data_iter = iter(train_loader)
images, labels = next(data_iter)

# %% [markdown]
# ### Show the First 8 Images

# %%
imshow(torchvision.utils.make_grid(images[:8]))

# %%
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size

# %%
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ### Define CNN Model

# %%
class BloodCellCNN(nn.Module):
    def __init__(self):
        super(BloodCellCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(64 * 56 * 56, 128)
        self.fc2 = nn.Linear(128, 2) 
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Initialize Model

# %%
model = BloodCellCNN()
print(model)
# Out:
# BloodCellCNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=200704, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=2, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %% [markdown]
# ### Train the Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# BloodCellCNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=200704, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=2, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
num_epochs = 10
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []

for epoch in range(num_epochs):
    # Training phase
    model.train()
    correct, total, running_loss = 0, 0, 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    train_loss = running_loss / len(train_loader)
    train_acc = correct / total

    # Validation phase
    model.eval()
    correct, total, val_loss = 0, 0, 0.0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    val_loss = val_loss / len(val_loader)
    val_acc = correct / total

    # Store losses and accuracies
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)

    print(f"Epoch {epoch+1}/{num_epochs} -> Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2%}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2%}")
# Out:
# Epoch 1/10 -> Train Loss: 0.8553, Train Acc: 73.39%, Val Loss: 0.0987, Val Acc: 97.14%
# Epoch 2/10 -> Train Loss: 0.1099, Train Acc: 95.36%, Val Loss: 0.0368, Val Acc: 98.57%
# Epoch 3/10 -> Train Loss: 0.0535, Train Acc: 97.86%, Val Loss: 0.0288, Val Acc: 98.57%
# Epoch 4/10 -> Train Loss: 0.1337, Train Acc: 95.18%, Val Loss: 0.0160, Val Acc: 99.29%
# Epoch 5/10 -> Train Loss: 0.0503, Train Acc: 98.21%, Val Loss: 0.0795, Val Acc: 97.14%
# Epoch 6/10 -> Train Loss: 0.0566, Train Acc: 97.50%, Val Loss: 0.0132, Val Acc: 99.29%
# Epoch 7/10 -> Train Loss: 0.0132, Train Acc: 100.00%, Val Loss: 0.0115, Val Acc: 100.00%
# Epoch 8/10 -> Train Loss: 0.0107, Train Acc: 100.00%, Val Loss: 0.0153, Val Acc: 99.29%
# Epoch 9/10 -> Train Loss: 0.0092, Train Acc: 100.00%, Val Loss: 0.0097, Val Acc: 100.00%
# Epoch 10/10 -> Train Loss: 0.0094, Train Acc: 99.82%, Val Loss: 0.0088, Val Acc: 100.00%

# %% [markdown]
# ### Plot Loss and Accuracy

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Training vs Validation Loss")

plt.subplot(1,2,2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Val Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Training vs Validation Accuracy")
plt.show()

plt.show()
